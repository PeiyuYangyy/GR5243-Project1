# %% [markdown]
# # Data Preparation

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
housing_price_data = pd.read_csv('/Users/peiyuyang/Desktop/GR5243/GR5243 Project 1/train.csv', index_col=False)

# %%
housing_price_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
housing_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
housing_price_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
fig,ax = plt.subplots(figsize = (20,18))
housing_price_data.hist(ax=ax)
plt.show()
# Out:
# /var/folders/_5/3vq_87vs1pl1h21kj21jj5f00000gn/T/ipykernel_95832/2276365644.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   housing_price_data.hist(ax=ax)

# %% [markdown]
# ### Check correlation

# %%
corr_matrix = housing_price_data.corr()
corr_matrix
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
price_corr = corr_matrix['SalePrice'].sort_values(ascending=False)
price_corr
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
from pandas.plotting import scatter_matrix
attributes = ["SalePrice", "OverallQual", "GrLivArea", "GarageCars","GarageArea","TotalBsmtSF"]
scatter_matrix(housing_price_data[attributes], figsize=(12, 8))
plt.show()

# %%
feature_name = ['OverallQual','GrLivArea','GarageCars','GarageArea','TotalBsmtSF']

# %% [markdown]
# ## Train and Test Split

# %%
X = housing_price_data[feature_name]
y = housing_price_data['SalePrice']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
X_train.head()
# Out:
#      OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF
# 318            7       2646           3         656         1347
# 580            6       1429           2         572         1144
# 961            6       2872           2         619         1330
# 78             4       1768           0           0         1768
# 5              5       1362           2         480          796

# %% [markdown]
# ## Data Cleaning

# %%
# Check na values
X_train.isna().sum()
# Out:
# OverallQual    0
# GrLivArea      0
# GarageCars     0
# GarageArea     0
# TotalBsmtSF    0
# dtype: int64

# %%
scatter_df = X_train.copy()
scatter_df['SalePrice'] = y_train

# %%
scatter_matrix(scatter_df, figsize=(12, 8))
plt.show()

# %%
# Check outliers
scatter_df.sort_values(by='GrLivArea', ascending=False)[:4]
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  SalePrice
# 1298           10       5642           2        1418         6110     160000
# 523            10       4676           3         884         3138     184750
# 1182           10       4476           3         813         2396     745000
# 691            10       4316           3         832         2444     755000

# %%
scatter_df.sort_values(by='TotalBsmtSF', ascending=False)[:4]
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  SalePrice
# 1298           10       5642           2        1418         6110     160000
# 496             8       3228           2         546         3200     430000
# 523            10       4676           3         884         3138     184750
# 440            10       2402           3         672         3094     555000

# %%
# From GrLivArea, the outliers are 1298 and 523(also from the scatter plot
# From TotalBsmtSF is the same
X_train = X_train.drop(1298)
X_train = X_train.drop(523)
y_train = y_train.drop(1298)
y_train = y_train.drop(523)

# %%
X_train
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF
# 318             7       2646           3         656         1347
# 580             6       1429           2         572         1144
# 961             6       2872           2         619         1330
# 78              4       1768           0           0         1768
# 5               5       1362           2         480          796
# ...           ...        ...         ...         ...          ...
# 1041            6       1632           2         484          800
# 1122            4        960           1         288          672
# 1346            7       2156           2         508         1568
# 1406            5        768           2         396          768
# 1389            6       1218           2         440          735
#
# [1166 rows x 5 columns]

# %%
y_train
# Out:
# 318     260000
# 580     181900
# 961     272000
# 78      136500
# 5       143000
#          ...
# 1041    173000
# 1122    112000
# 1346    262500
# 1406    133000
# 1389    131000
# Name: SalePrice, Length: 1166, dtype: int64

# %% [markdown]
# # Model Fitting and hyperparameter Tuning

# %% [markdown]
# ## Multi-Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()
mlr.fit(X_train, y_train)
for feature, coeff in zip(list(X_train.columns), mlr.coef_):
    if coeff > 0:
        positive_fea = feature
        positive_co = coeff
        print(f'{positive_fea} has a positive relationship {positive_co:.2f}')
    else:
        print(f' {feature} has the coefficient {coeff:.2f}')
# Out:
# OverallQual has a positive relationship 21476.32
# GrLivArea has a positive relationship 51.52
# GarageCars has a positive relationship 6779.65
# GarageArea has a positive relationship 35.28
# TotalBsmtSF has a positive relationship 47.22

# %%
# mlr_training_r2 = mlr.score(X_train, y_train)
# print(f'mlr training set R^2: {mlr_training_r2:.2f}')

# %%
# X_test.isna().sum(), y_test.isna().sum()

# %%
# mlr_test_r2 = mlr.score(X_test, y_test)
# print(f'mlr test R^2: {mlr_test_r2:.2f}')

# %%
from sklearn.model_selection import cross_val_score
mlr_cv_scores = cross_val_score(LinearRegression(), X_train, y_train, cv=10)
mlr_cv_mean = mlr_cv_scores.mean()

mlr_cv_2std = 2*mlr_cv_scores.std()

print(f'mlr mean cv r2: {mlr_cv_mean:.2f} +- {mlr_cv_2std:.2f}')
# Out:
# mlr mean cv r2: 0.80 +- 0.06

# %% [markdown]
# ## Decision Tree Regressor Model

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

params_dtr = {'max_depth': [1, 2, 3, 5, 10]}

dtr_gscv = GridSearchCV(DecisionTreeRegressor(random_state=123), params_dtr, cv=10, refit=True, n_jobs=-1).fit(X_train, y_train)

print(f'dtr best hyperparams      : {dtr_gscv.best_params_}')
print(f'dtr best mean cv accuracy : {dtr_gscv.best_score_:.3f}')
# Out:
# dtr best hyperparams      : {'max_depth': 5}
# dtr best mean cv accuracy : 0.760

# %%
# dtr = DecisionTreeRegressor(max_depth=5)
# dtr.fit(X_train,y_train)
# dtr_train_r2 = dtr.score(X_train,y_train)
# print(f'dtr train R^2: {dtr_train_r2:.2f}')

# %%
# dtr_test_r2 = dtr.score(X_test, y_test)
# print(f'dtr test R^2: {dtr_test_r2:.2f}')

# %%
dtr_cv_scores = cross_val_score(DecisionTreeRegressor(max_depth=5, random_state=123), X_train, y_train, cv=10)
dtr_cv_mean = dtr_cv_scores.mean()

dtr_cv_2std = 2*dtr_cv_scores.std()

print(f'dtr mean cv r2: {dtr_cv_mean:.3f} +- {dtr_cv_2std:.3f}')
# Out:
# dtr mean cv r2: 0.760 +- 0.090

# %% [markdown]
# ## Gradient Boosting Regressor Model

# %%
from sklearn.ensemble import GradientBoostingRegressor

params_gbr = {'n_estimators': [10, 50, 100, 200, 500], 'max_depth': [1, 2, 3, 5, 10]}

gbr_gscv = GridSearchCV(GradientBoostingRegressor(random_state=123), params_gbr, cv=10 ,refit=True, n_jobs=-1).fit(X_train, y_train)

print(f'gbr best hyperparams      : {gbr_gscv.best_params_}')
print(f'gbr best mean cv accuracy : {gbr_gscv.best_score_:.3f}')
# Out:
# gbr best hyperparams      : {'max_depth': 3, 'n_estimators': 50}
# gbr best mean cv accuracy : 0.848

# %%
gbr_cv_scores = cross_val_score(GradientBoostingRegressor(n_estimators=50, max_depth=3, random_state=123), X_train, y_train, cv=10, n_jobs=-1)
gbr_cv_mean = gbr_cv_scores.mean()
gbr_cv_2std = 2*gbr_cv_scores.std()
print(f'gbr mean cv r2: {gbr_cv_mean:.3f} +- {gbr_cv_2std:.3f}')
# Out:
# gbr mean cv r2: 0.848 +- 0.074

# %% [markdown]
# ## XGBoost Regressor Model

# %%
from xgboost import XGBRegressor

params_xgbr = {'n_estimators': [10, 50, 100, 200, 500], 'max_depth': [1, 2, 3, 5, 10], 'learning_rate': [0.01,0.1,0.5,1.0]}

xgbr_gscv = GridSearchCV(XGBRegressor(random_state=123), params_xgbr, cv=10 ,refit=True, n_jobs=-1).fit(X_train, y_train)

print(f'xgbr best hyperparams      : {xgbr_gscv.best_params_}')
print(f'xgbr best mean cv accuracy : {xgbr_gscv.best_score_:.3f}')
# Out:
# xgbr best hyperparams      : {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# xgbr best mean cv accuracy : 0.842

# %%
xgbr_cv_scores = cross_val_score(XGBRegressor(n_estimators=50, learning_rate=0.1, max_depth=3, random_state=123),X_train, y_train, cv=10, n_jobs=-1)
xgbr_cv_mean = xgbr_cv_scores.mean()
xgbr_cv_2std = 2*xgbr_cv_scores.std()
print(f'xgbr mean cv r2: {xgbr_cv_mean:.3f} +- {xgbr_cv_2std:.3f}')
# Out:
# xgbr mean cv r2: 0.842 +- 0.072

# %% [markdown]
# # Model Cross-Validation Score

# %%
result_mean_cv = {"mlr":f'{mlr_cv_mean:.3f} +- {mlr_cv_2std:.3f}', "dtr":f'{dtr_cv_mean:.3f} +- {dtr_cv_2std:.3f}', "gbr":f'{gbr_cv_mean:.3f} +- {gbr_cv_2std:.3f}', "xgbr":f'{xgbr_cv_mean:.3f} +- {xgbr_cv_2std:.3f}'}

# %%
result_mean_cv_df = pd.DataFrame.from_dict(result_mean_cv, orient="index", columns=["Cross-Validation Scores"])

# %%
result_mean_cv_df
# Out:
#      Cross-Validation Scores
# mlr           0.799 +- 0.060
# dtr           0.760 +- 0.090
# gbr           0.848 +- 0.074
# xgbr          0.842 +- 0.072

# %% [markdown]
# ### The best model found is XGBoost Regressor Model

# %% [markdown]
# # Prediction from test dataset

# %%
gbr_test = GradientBoostingRegressor(n_estimators=50, max_depth=3, random_state=123).fit(X_train, y_train)

gbr_test_score = gbr_test.score(X_test, y_test)
print(f'gbr test accuracy: {gbr_test_score: .3f}')
# Out:
# gbr test accuracy:  0.862

# %%
data_test = pd.read_csv('/Users/peiyuyang/Desktop/GR5243/GR5243 Project 1/test.csv', index_col=False)

# %%
X_data = data_test[['OverallQual','GrLivArea','GarageCars','GarageArea','TotalBsmtSF']]
X_data.head()
# Out:
#    OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF
# 0            5        896         1.0       730.0        882.0
# 1            6       1329         1.0       312.0       1329.0
# 2            5       1629         2.0       482.0        928.0
# 3            6       1604         2.0       470.0        926.0
# 4            8       1280         2.0       506.0       1280.0

# %%
#Checking missing value in test data set

total_missing_values_X_data=X_data.isnull().sum().sort_values(ascending=False)
total_missing_values_X_data
# Out:
# GarageCars     1
# GarageArea     1
# TotalBsmtSF    1
# OverallQual    0
# GrLivArea      0
# dtype: int64

# %% [markdown]
# We will update that with the mean value in 'Garage Cars', 'Garage Area', and 'TotalBsmtSF'.

# %%
X_data = X_data.copy()
X_data.GarageCars.fillna(X_data.GarageCars.mean(), inplace=True)

# %%
X_data.GarageArea.fillna(X_data.GarageArea.mean(), inplace=True)

# %%
X_data.TotalBsmtSF.fillna(X_data.TotalBsmtSF.mean(), inplace=True)

# %%
X_data.isnull().sum().sort_values(ascending=False)
# Out:
# OverallQual    0
# GrLivArea      0
# GarageCars     0
# GarageArea     0
# TotalBsmtSF    0
# dtype: int64

# %%
X_data
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF
# 0               5        896         1.0       730.0        882.0
# 1               6       1329         1.0       312.0       1329.0
# 2               5       1629         2.0       482.0        928.0
# 3               6       1604         2.0       470.0        926.0
# 4               8       1280         2.0       506.0       1280.0
# ...           ...        ...         ...         ...          ...
# 1454            4       1092         0.0         0.0        546.0
# 1455            4       1092         1.0       286.0        546.0
# 1456            5       1224         2.0       576.0       1224.0
# 1457            5        970         0.0         0.0        912.0
# 1458            7       2000         3.0       650.0        996.0
#
# [1459 rows x 5 columns]

# %%
#Creating predictions based on X_test_c
y_pred = gbr_test.predict(X_data)
y_pred
# Out:
# array([124057.7339294 , 149327.09064044, 152472.08651188, ...,
#        150740.69108755, 110718.45717833, 233176.49175549])

# %%
prediction_data = X_data.copy()

# %%
prediction_data ['SalePrice_Predicted'] = y_pred

# %%
prediction_data
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# 0               5        896         1.0       730.0        882.0
# 1               6       1329         1.0       312.0       1329.0
# 2               5       1629         2.0       482.0        928.0
# 3               6       1604         2.0       470.0        926.0
# 4               8       1280         2.0       506.0       1280.0
# ...           ...        ...         ...         ...          ...
# 1454            4       1092         0.0         0.0        546.0
# 1455            4       1092         1.0       286.0        546.0
# 1456            5       1224         2.0       576.0       1224.0
# 1457            5        970         0.0         0.0        912.0
# 1458            7       2000         3.0       650.0        996.0
#
#       SalePrice_Predicted
# 0           124057.733929
# 1           149327.090640
# 2           152472.086512
# 3           170753.617365
# 4           217980.915937
# ...

# %%
prediction_data.SalePrice_Predicted.describe()
# Out:
# count      1459.000000
# mean     179906.889226
# std       74217.003594
# min       62388.921114
# 25%      130985.898991
# 50%      160269.799207
# 75%      208992.657022
# max      709045.639264
# Name: SalePrice_Predicted, dtype: float64

# %%
import matplotlib.pyplot as plt

# create scatter plots for each category vs. sale price prediction
fig, axs = plt.subplots(1, 5, figsize=(30, 5))

axs[0].scatter(prediction_data['OverallQual'], prediction_data['SalePrice_Predicted'])
axs[0].set_xlabel('Overall Quality')
axs[0].set_ylabel('Sale Price Prediction')

axs[1].scatter(prediction_data['GrLivArea'], prediction_data['SalePrice_Predicted'])
axs[1].set_xlabel('Above Ground Living Area')
axs[1].set_ylabel('Sale Price Prediction')

axs[2].scatter(prediction_data['GarageCars'], prediction_data['SalePrice_Predicted'])
axs[2].set_xlabel('Number of Garage Cars')
axs[2].set_ylabel('Sale Price Prediction')

axs[3].scatter(prediction_data['GarageArea'], prediction_data['SalePrice_Predicted'])
axs[3].set_xlabel('Garage Area')
axs[3].set_ylabel('Sale Price Prediction')

axs[4].scatter(prediction_data['TotalBsmtSF'], prediction_data['SalePrice_Predicted'])
axs[4].set_xlabel('Total Basement Square Feet')
axs[4].set_ylabel('Sale Price Prediction')

plt.show()

# %%
import matplotlib.pyplot as plt

importance = gbr_test.feature_importances_
categories = ['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF']

plt.bar(categories, importance)
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('Importance Score')
plt.title('Feature Importance Plot')

plt.show()
